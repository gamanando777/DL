# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 경고가 뜨지 않도록..
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False

# 출력 창 청소
from IPython.display import clear_output

import time

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 딥러닝
import tensorflow as tf

# 딥러닝 모델 구조를 정의하는 것
from tensorflow.keras.models import Sequential
# 층 모델(은닉층과 출력층)
from tensorflow.keras.layers import Dense
# 활성화 함수를 정의하는 것
from tensorflow.keras.layers import Activation
# CNN : 커널을 통해 합성곱을 구하는 것. 이미지의 특징을 두드러지게 한다.
from tensorflow.keras.layers import Conv2D
# MaxPooling : 불필요한 부분을 제거하는 역할을 한다
from tensorflow.keras.layers import MaxPool2D
# Flatten : CNN, MaxPooling은 2차원 데이터를 사용하고 출력하기 때문에
# 1차원 데이터로 변하는 것을 사용해야 한다.
from tensorflow.keras.layers import Flatten
# Dropout : 노드의 일부를 on/off 하면서 과적합을 예방한다.
from tensorflow.keras.layers import Dropout
# Embedding : 주어진 단어 데이터를 원핫 인코딩하고 차원축소를 한다.
from tensorflow.keras.layers import Embedding
# 문장 학습을 위한 RNN(LSTM)
from tensorflow.keras.layers import LSTM
# Cnn1D
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPool1D


# 데이터 표준화
from sklearn.preprocessing import StandardScaler
# 문자열을 숫자로 변환
from sklearn.preprocessing import LabelEncoder
# 원핫 인코딩
from tensorflow.keras.utils import to_categorical

# 학습데이터와 검증데이터로 나눈다
from sklearn.model_selection import train_test_split

# K폴드 교차검증
from sklearn.model_selection import KFold

# 저장된 모델을 복원한다.
from tensorflow.keras.models import load_model

# epoch 마다 저장을 하기 위해 사용한다.
from tensorflow.keras.callbacks import ModelCheckpoint
# 조기 중단을 위해 사용한다.
from tensorflow.keras.callbacks import EarlyStopping

# 문장을 잘라준다.
from tensorflow.keras.preprocessing.text import Tokenizer
# 모든 문장의 데이터의 단어 데이터 수를 동일한 수로 맞춰준다.
from tensorflow.keras.preprocessing.sequence import pad_sequences
# 문자열을 단어사전으로 만들어준다.
from tensorflow.keras.preprocessing.text import text_to_word_sequence

import os
import glob
from PIL import Image


# GPU 할당
gpus = tf.config.experimental.list_physical_devices('GPU')
# GPU가 있다면..
if len(gpus) > 0 :
    try :
        for gpu in gpus :
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e :
        print(e)

# %%
# seed 설정
np.random.seed(1)
tf.random.set_seed(1)

# %%
# 폴더 목록을 가져온다.
root_dir = '101_ObjectCategories'

a1 = os.walk(root_dir)
categories = list(a1)[0][1]

# 수업 실습을 위해...(나중에 주석처리해서 테스트 해보세요)
categories = categories[:5]

categories
# Out:
# ['accordion', 'airplanes', 'anchor', 'ant', 'BACKGROUND_Google']

# %%
# 이미지를 복원한다.
X_train, X_test, y_train, y_test = np.load('101_new2.npy',
                                          allow_pickle=True)

# %%
# 데이터 정규화(0 ~ 1 사이로.)
X_train = X_train.astype('float') / 255
X_test = X_test.astype('float') / 255

print(X_train.shape)
print(X_test.shape)
# Out:
# (17926, 64, 64, 3)
# (5976, 64, 64, 3)

# %%
# 결과 데이터 원핫 인코딩
y_train = to_categorical(y_train, len(categories))
y_test = to_categorical(y_test, len(categories))

# %%
# 모델 구축하기
model = Sequential()

# padding : CNN은 이미지의 사이즈가 줄어든다.
# padding에 same을 주게되면 줄어든 사이즈 만큼 0으로 채워서
# 이미지 데이터의 크기를 유지시켜준다.
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=(64, 64, 3), 
                padding='same'))
model.add(Activation('relu'))
model.add(MaxPool2D(pool_size=4))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(64, kernel_size=(3, 3)))
model.add(MaxPool2D(pool_size=4))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(len(categories)))
model.add(Activation('softmax'))

# %%
# 모델들이 저장될 파일명
# epoch : 학습 횟수
# val_loss : 검증 데이터 손실률
path1 = 'model/29/{epoch}-{val_loss}.h5'
path2 = 'model/29/최종.h5'

# 저장 콜백 설정
# save_best_only : True로 설정하면 개선이 되었을 때만 저장한다.
call1 = ModelCheckpoint(filepath=path1, monitor='val_loss', 
                        save_best_only=True)
call2 = ModelCheckpoint(filepath=path2, monitor='val_loss',
                        save_best_only=True)

# 조기 중단 콜백
# patience : 개선이 된 이후 몇 번을 더 볼 것인가를 설정한다.
# 이 횟수 동안 개선이 되지 않으면 중단 시킨다.
call3 = EarlyStopping(monitor='val_loss', patience=50)

# %%
# 학습 모델을 생성한다.(다중분류)
model.compile(loss='categorical_crossentropy', optimizer='adam', 
              metrics=['accuracy'])

# %%
# 학습한다.
with tf.device('/CPU:0') :
    history = model.fit(X_train, y_train, epochs=2000, batch_size=500, 
          validation_data=[X_test, y_test],
          callbacks=[call1, call2, call3])
# Out:
# Epoch 1/2000
# 36/36 [==============================] - 18s 498ms/step - loss: 0.8622 - accuracy: 0.6800 - val_loss: 0.5571 - val_accuracy: 0.8245
# Epoch 2/2000
# 36/36 [==============================] - 17s 477ms/step - loss: 0.4861 - accuracy: 0.8400 - val_loss: 0.4072 - val_accuracy: 0.8586
# Epoch 3/2000
# 36/36 [==============================] - 18s 495ms/step - loss: 0.3350 - accuracy: 0.8856 - val_loss: 0.2678 - val_accuracy: 0.9115
# Epoch 4/2000
# 36/36 [==============================] - 18s 499ms/step - loss: 0.2563 - accuracy: 0.9112 - val_loss: 0.2112 - val_accuracy: 0.9284
# Epoch 5/2000
# 36/36 [==============================] - 18s 503ms/step - loss: 0.2154 - accuracy: 0.9240 - val_loss: 0.1784 - val_accuracy: 0.9403
# Epoch 6/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.1800 - accuracy: 0.9367 - val_loss: 0.1605 - val_accuracy: 0.9491
# Epoch 7/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.1544 - accuracy: 0.9477 - val_loss: 0.1458 - val_accuracy: 0.9550
# Epoch 8/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.1387 - accuracy: 0.9517 - val_loss: 0.1266 - val_accuracy: 0.9602
# Epoch 9/2000
# 36/36 [==============================] - 18s 501ms/step - loss: 0.1210 - accuracy: 0.9582 - val_loss: 0.0976 - val_accuracy: 0.9734
# Epoch 10/2000
# 36/36 [==============================] - 18s 500ms/step - loss: 0.1018 - accuracy: 0.9652 - val_loss: 0.0765 - val_accuracy: 0.9801
# Epoch 11/2000
# 36/36 [==============================] - 18s 492ms/step - loss: 0.0928 - accuracy: 0.9676 - val_loss: 0.0700 - val_accuracy: 0.9766
# Epoch 12/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.0832 - accuracy: 0.9724 - val_loss: 0.0790 - val_accuracy: 0.9764
# Epoch 13/2000
# 36/36 [==============================] - 18s 494ms/step - loss: 0.0703 - accuracy: 0.9770 - val_loss: 0.0546 - val_accuracy: 0.9841
# Epoch 14/2000
# 36/36 [==============================] - 18s 497ms/step - loss: 0.0643 - accuracy: 0.9780 - val_loss: 0.0486 - val_accuracy: 0.9866
# Epoch 15/2000
# 36/36 [==============================] - 18s 508ms/step - loss: 0.0545 - accuracy: 0.9813 - val_loss: 0.0342 - val_accuracy: 0.9901
# Epoch 16/2000
# 36/36 [==============================] - 18s 503ms/step - loss: 0.0500 - accuracy: 0.9840 - val_loss: 0.0361 - val_accuracy: 0.9885
# Epoch 17/2000
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0457 - accuracy: 0.9840 - val_loss: 0.0296 - val_accuracy: 0.9921
# Epoch 18/2000
# 36/36 [==============================] - 18s 508ms/step - loss: 0.0410 - accuracy: 0.9860 - val_loss: 0.0212 - val_accuracy: 0.9941
# Epoch 19/2000
# 36/36 [==============================] - 18s 497ms/step - loss: 0.0396 - accuracy: 0.9863 - val_loss: 0.0333 - val_accuracy: 0.9886
# Epoch 20/2000
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0420 - accuracy: 0.9856 - val_loss: 0.0186 - val_accuracy: 0.9941
# Epoch 21/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0292 - accuracy: 0.9910 - val_loss: 0.0186 - val_accuracy: 0.9943
# Epoch 22/2000
# 36/36 [==============================] - 18s 492ms/step - loss: 0.0295 - accuracy: 0.9894 - val_loss: 0.0122 - val_accuracy: 0.9965
# Epoch 23/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0251 - accuracy: 0.9919 - val_loss: 0.0122 - val_accuracy: 0.9967
# Epoch 24/2000
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.0106 - val_accuracy: 0.9975
# Epoch 25/2000
# 36/36 [==============================] - 18s 499ms/step - loss: 0.0245 - accuracy: 0.9920 - val_loss: 0.0208 - val_accuracy: 0.9928
# Epoch 26/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 0.0131 - val_accuracy: 0.9958
# Epoch 27/2000
# 36/36 [==============================] - 18s 496ms/step - loss: 0.0248 - accuracy: 0.9915 - val_loss: 0.0106 - val_accuracy: 0.9972
# Epoch 28/2000
# 36/36 [==============================] - 18s 495ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 0.0115 - val_accuracy: 0.9967
# Epoch 29/2000
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0200 - accuracy: 0.9926 - val_loss: 0.0075 - val_accuracy: 0.9980
# Epoch 30/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0151 - accuracy: 0.9956 - val_loss: 0.0082 - val_accuracy: 0.9985
# Epoch 31/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0162 - accuracy: 0.9948 - val_loss: 0.0091 - val_accuracy: 0.9973
# Epoch 32/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0179 - accuracy: 0.9939 - val_loss: 0.0130 - val_accuracy: 0.9955
# Epoch 33/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.0113 - val_accuracy: 0.9955
# Epoch 34/2000
# 36/36 [==============================] - 18s 492ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.0056 - val_accuracy: 0.9975
# Epoch 35/2000
# 36/36 [==============================] - 18s 500ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0100 - val_accuracy: 0.9963
# Epoch 36/2000
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0115 - accuracy: 0.9964 - val_loss: 0.0044 - val_accuracy: 0.9985
# Epoch 37/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.0045 - val_accuracy: 0.9983
# Epoch 38/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.0061 - val_accuracy: 0.9988
# Epoch 39/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0151 - accuracy: 0.9950 - val_loss: 0.0076 - val_accuracy: 0.9978
# Epoch 40/2000
# 36/36 [==============================] - 18s 492ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0069 - val_accuracy: 0.9985
# Epoch 41/2000
# 36/36 [==============================] - 18s 493ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.0034 - val_accuracy: 0.9995
# Epoch 42/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0041 - val_accuracy: 0.9995
# Epoch 43/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0060 - val_accuracy: 0.9983
# Epoch 44/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0106 - accuracy: 0.9957 - val_loss: 0.0034 - val_accuracy: 0.9997
# Epoch 45/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 46/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0036 - val_accuracy: 0.9992
# Epoch 47/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0055 - val_accuracy: 0.9990
# Epoch 48/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.0088 - accuracy: 0.9973 - val_loss: 0.0046 - val_accuracy: 0.9982
# Epoch 49/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0036 - val_accuracy: 0.9988
# Epoch 50/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0058 - val_accuracy: 0.9985
# Epoch 51/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0042 - val_accuracy: 0.9987
# Epoch 52/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0027 - val_accuracy: 0.9997
# Epoch 53/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0027 - val_accuracy: 0.9993
# Epoch 54/2000
# 36/36 [==============================] - 18s 492ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0038 - val_accuracy: 0.9988
# Epoch 55/2000
# 36/36 [==============================] - 18s 487ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0030 - val_accuracy: 0.9995
# Epoch 56/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0019 - val_accuracy: 0.9995
# Epoch 57/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 0.0034 - val_accuracy: 0.9988
# Epoch 58/2000
# 36/36 [==============================] - 18s 497ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0034 - val_accuracy: 0.9988
# Epoch 59/2000
# 36/36 [==============================] - 18s 499ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 60/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0049 - val_accuracy: 0.9983
# Epoch 61/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0032 - val_accuracy: 0.9990
# Epoch 62/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0040 - val_accuracy: 0.9987
# Epoch 63/2000
# 36/36 [==============================] - 17s 486ms/step - loss: 0.0068 - accuracy: 0.9973 - val_loss: 0.0055 - val_accuracy: 0.9987
# Epoch 64/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0057 - val_accuracy: 0.9982
# Epoch 65/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.0031 - val_accuracy: 0.9993
# Epoch 66/2000
# 36/36 [==============================] - 17s 486ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 67/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0078 - accuracy: 0.9974 - val_loss: 0.0036 - val_accuracy: 0.9985
# Epoch 68/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0049 - val_accuracy: 0.9982
# Epoch 69/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0030 - val_accuracy: 0.9993
# Epoch 70/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0040 - val_accuracy: 0.9985
# Epoch 71/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0090 - accuracy: 0.9964 - val_loss: 0.0020 - val_accuracy: 0.9993
# Epoch 72/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0027 - val_accuracy: 0.9995
# Epoch 73/2000
# 36/36 [==============================] - 18s 492ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0021 - val_accuracy: 0.9995
# Epoch 74/2000
# 36/36 [==============================] - 18s 502ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.0037 - val_accuracy: 0.9983
# Epoch 75/2000
# 36/36 [==============================] - 18s 489ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0051 - val_accuracy: 0.9982
# Epoch 76/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0028 - val_accuracy: 0.9990
# Epoch 77/2000
# 36/36 [==============================] - 18s 498ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0052 - val_accuracy: 0.9980
# Epoch 78/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0072 - accuracy: 0.9978 - val_loss: 0.0026 - val_accuracy: 0.9990
# Epoch 79/2000
# 36/36 [==============================] - 18s 495ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0026 - val_accuracy: 0.9988
# Epoch 80/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.0057 - accuracy: 0.9983 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 81/2000
# 36/36 [==============================] - 18s 488ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0013 - val_accuracy: 0.9995
# Epoch 82/2000
# 36/36 [==============================] - 18s 487ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0034 - val_accuracy: 0.9987
# Epoch 83/2000
# 36/36 [==============================] - 18s 491ms/step - loss: 0.0035 - accuracy: 0.9987 - val_loss: 0.0029 - val_accuracy: 0.9990
# Epoch 84/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0031 - val_accuracy: 0.9988
# Epoch 85/2000
# 36/36 [==============================] - 18s 490ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.0038 - val_accuracy: 0.9988
# Epoch 86/2000
# 36/36 [==============================] - 18s 505ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0028 - val_accuracy: 0.9993
# Epoch 87/2000
# 36/36 [==============================] - 18s 509ms/step - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.0021 - val_accuracy: 0.9993
# Epoch 88/2000
# 36/36 [==============================] - 18s 507ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0026 - val_accuracy: 0.9993
# Epoch 89/2000
# 36/36 [==============================] - 18s 506ms/step - loss: 0.0082 - accuracy: 0.9977 - val_loss: 0.0047 - val_accuracy: 0.9987
# Epoch 90/2000
# 36/36 [==============================] - 18s 508ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0029 - val_accuracy: 0.9988
# Epoch 91/2000
#  6/36 [====>.........................] - ETA: 13s - loss: 0.0072 - accuracy: 0.9970
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-89aa7fe7e71f> in <module>
#       1 # 학습한다.
#       2 with tf.device('/CPU:0') :
# ----> 3     history = model.fit(X_train, y_train, epochs=2000, batch_size=500,
#       4           validation_data=[X_test, y_test],
#       5           callbacks=[call1, call2, call3])
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# 모델을 복원한다.
model2 = load_model(path2)
model2

# %%
with tf.device('/CPU:0') :
    a1 = model2.evaluate(X_test, y_test)
    print(f'손실률 : {a1[0]}')
    print(f'정확도 : {a1[1]}')
# Out:
# 187/187 [==============================] - 2s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# 손실률 : 0.0011280947364866734
# 정확도 : 1.0

# %%
# 오차 정도와 정확도를 그래프로 그린다.
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
